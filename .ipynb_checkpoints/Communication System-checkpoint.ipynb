# %%
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

import numpy             as np
import matplotlib.pyplot as plt

plt.rcParams['figure.dpi'] = 300

from numpy.fft    import rfft, irfft, rfftfreq
from numpy.random import normal
from random       import choice
from math         import ceil

import sys
np.set_printoptions(threshold=sys.maxsize)

# %%
Fs = 22050
Ts = 1/Fs

A = 1
K = 15
W = 2000

BITS_PER_BYTE    = 8
NUMBERS_OF_BYTES = 9
NUMBER_OF_BITS   = NUMBERS_OF_BYTES * BITS_PER_BYTE
SIGNAL_LENGTH    = NUMBER_OF_BITS * K

FREQUENCY_1 = 2000
FREQUENCY_2 = 4000
FREQUENCY_3 = 6000
FREQUENCY_4 = 8000

t = np.linspace(0, Ts*NUMBER_OF_BITS, SIGNAL_LENGTH)
f = rfftfreq(SIGNAL_LENGTH, Ts)
bits = [A if b else -A for b in [choice([True, False]) for _ in range(NUMBER_OF_BITS)]]
white_noise = normal(0, 0.05, SIGNAL_LENGTH)

def passband_filter(frequencies, omega, width):
    filter = np.zeros(frequencies.size)
    for i in np.argwhere(abs(abs(frequencies)-omega) <= width/2):
        filter[i] = 1
    return filter

def decoder(signal_input):
    signal_output = []
    
    for i in range(NUMBER_OF_BITS):
        acc = 0
        for j in range(K):
            acc += signal_input[i * K + j]
        signal_output.append(acc//K)
        
    return signal_output

def cos_modulator(omega):
    return np.array([np.cos(2*np.pi*omega*a*Ts) for a in range(SIGNAL_LENGTH)])

def modulator():
    return (cos_modulator(FREQUENCY_1) + \
            cos_modulator(FREQUENCY_2) + \
            cos_modulator(FREQUENCY_3) + \
            cos_modulator(FREQUENCY_4)) / 4

# %%
signal = np.repeat(bits, K)
noisy_signal = signal + white_noise
cropped_signal = irfft(rfft(signal) * passband_filter(f, 0, W))
noisy_cropped_signal = cropped_signal + white_noise
plt.plot(t, signal)
plt.plot(t, noisy_signal)
plt.plot(t, cropped_signal)
plt.plot(t, noisy_cropped_signal)
plt.show()

# %%
signal_frequencies = rfft(signal)
plt.plot(f, abs(signal_frequencies))
plt.show()

# %%
cropped_signal_frequencies = rfft(signal) * passband_filter(f, 0, W)
plt.plot(f, abs(rfft(irfft(cropped_signal_frequencies)*cos_modulator(FREQUENCY_1))))
plt.show()

# %%
sent_signal = modulator() * signal
plt.plot(t, sent_signal)
plt.show()

# %%
sent_signal_frequencies = rfft(sent_signal)
plt.plot(f, abs(sent_signal_frequencies))
plt.show()

# %%
noisy_sent_signal = sent_signal+white_noise
plt.plot(t, noisy_sent_signal)
plt.show()

# %%
noisy_sent_signal_frequencies = rfft(noisy_sent_signal)
plt.plot(f, abs(noisy_sent_signal_frequencies))
plt.show()

# %%
noisy_sent_signal_frequencies_dropped_FREQUENCY_3 = noisy_sent_signal_frequencies * (passband_filter(f, FREQUENCY_1, W) + passband_filter(f, FREQUENCY_2, W) + passband_filter(f, FREQUENCY_4, W))
plt.plot(f, noisy_sent_signal_frequencies_dropped_FREQUENCY_3)
plt.show()
np.savetxt("b.txt", irfft(noisy_sent_signal_frequencies_dropped_FREQUENCY_3))

# %%
def cos_demodulator(signal, omega):
    signal_frequencies = rfft(signal) * passband_filter(f, omega, W)
    demodulated_signal_frequencies = rfft(irfft(signal_frequencies) * cos_modulator(omega)) * passband_filter(f, 0, W)
    return irfft(demodulated_signal_frequencies)

def demodulator(signal):
    return 2 * 4/3 * (cos_demodulator(signal, FREQUENCY_1) + cos_demodulator(signal, FREQUENCY_2) + cos_demodulator(signal, FREQUENCY_3) + cos_demodulator(signal, FREQUENCY_4))


a = demodulator(irfft(noisy_sent_signal_frequencies_dropped_FREQUENCY_3))
plt.plot(t, a)
plt.plot(t, signal)
plt.plot(t, [1 if s > 0 else -1 for s in signal])
plt.show()

# %%
signal   = np.loadtxt("res/in/test-sent-signal.txt")
bits     = np.loadtxt("res/in/test-bits.txt")
expected = np.repeat(bits, K)

got = demodulator(signal)
plt.plot(t, got)
plt.plot(t, expected)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-407c8dea1c13> in <module>
#       3 expected = np.repeat(bits, K)
#       4
# ----> 5 got = demodulator(signal)
#       6 plt.plot(t, got)
#       7 plt.plot(t, expected)
#
# <ipython-input-15-056d9b825514> in demodulator(signal)
#       5
#       6 def demodulator(signal):
# ----> 7     return 2 * 4/3 * (cos_demodulator(signal, FREQUENCY_1) + cos_demodulator(signal, FREQUENCY_2) + cos_demodulator(signal, FREQUENCY_3) + cos_demodulator(signal, FREQUENCY_4))
#       8
#       9
#
# <ipython-input-15-056d9b825514> in cos_demodulator(signal, omega)
#       1 def cos_demodulator(signal, omega):
# ----> 2     signal_frequencies = rfft(signal) * passband_filter(f, omega, W)
#       3     demodulated_signal_frequencies = rfft(irfft(signal_frequencies) * cos_modulator(omega)) * passband_filter(f, 0, W)
#       4     return irfft(demodulated_signal_frequencies)
#       5
#
# ValueError: operands could not be broadcast together with shapes (616,) (541,)
